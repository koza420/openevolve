# %%
# !git clone https://github.com/algorithmicsuperintelligence/openevolve.git
# %cd openevolve
# !pip -q install -e .
# Out:
# Cloning into 'openevolve'...
# remote: Enumerating objects: 4958, done.
# remote: Counting objects: 100% (1874/1874), done.
# remote: Compressing objects: 100% (739/739), done.
# remote: Total 4958 (delta 1240), reused 1135 (delta 1135), pack-reused 3084 (from 2)
# Receiving objects: 100% (4958/4958), 5.86 MiB | 13.86 MiB/s, done.
# Resolving deltas: 100% (2638/2638), done.
# /content/openevolve

# %%
from google.colab import userdata
import os

key = userdata.get("OPENAI_API_KEY")   # must match the secret name exactly
if not key:
    raise ValueError("OPENAI_API_KEY secret not found in Colab Secrets")

os.environ["OPENAI_API_KEY"] = key
print("Loaded OPENAI_API_KEY:", key[:7] + "...")
# Out:
# Loaded OPENAI_API_KEY: sk-proj...

# %%
# %%bash
# python openevolve-run.py examples/function_minimization/initial_program.py \
#   examples/function_minimization/evaluator.py \
#   --config examples/function_minimization/config.yaml \
#   --iterations 50
# Out:
# Evolution complete!
# Best program metrics:
#   runs_successfully: 1.0000
#   value_score: 0.9418
#   distance_score: 0.7566
#   combined_score: 1.2148
#
# Latest checkpoint saved at: examples/function_minimization/openevolve_output/checkpoints/checkpoint_50
# To resume, use: --checkpoint examples/function_minimization/openevolve_output/checkpoints/checkpoint_50
# 2026-01-07 13:26:06,518 - INFO - Logging to examples/function_minimization/openevolve_output/logs/openevolve_20260107_132606.log
# 2026-01-07 13:26:06,523 - INFO - Set random seed to 42 for reproducibility
# 2026-01-07 13:26:06,751 - INFO - Initialized OpenAI LLM with model: gemini-2.5-flash-lite
# 2026-01-07 13:26:06,797 - INFO - Initialized OpenAI LLM with model: gemini-2.5-flash
# 2026-01-07 13:26:06,797 - INFO - Initialized LLM ensemble with models: gemini-2.5-flash-lite (weight: 0.80), gemini-2.5-flash (weight: 0.20)
# ...
